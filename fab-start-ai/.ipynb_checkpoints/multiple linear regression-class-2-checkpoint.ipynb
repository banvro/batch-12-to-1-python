# %%
Simple linear regression:
    1) regression:
        1) simple linear regression
        2) multiple linear regression
        3) polynomial regression.......
    2) classification

# %%
1) simple linear regression:

# %%
y = mx + b

# %%
pkg = slop * cgpa + intercept

# %%
# 2) multiple linear regression :

# %%
cgpa | pkg

# %%
cgpa | iq | age | pkg

# %%
# model.codi_

# %%
# [12.099]

# %%
y = mx + b

# %%
y = m1x1 + m2x2 + m3x3 + b

# %%
b => B0

# %%
m1 ---> B1
m2 ----> B2
m3 -----> B3
.
..
.mn -----> Bn

# %%
# y = B0 + B1X1 + B2X2 + B3X3 + ...... + BnXn

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Student_Performance.csv")

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.head(2)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0

# %%
# plotly

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
# import matplotlib.pyplot

# %%
px.scatter_3d(data, x = data["Hours Studied"], y = data["Previous Scores"], z = data["Performance Index"])

# %%
2d ----> line

3d ---> plane

4d ----> hyperplane
5d --> hyperplane
.
.
.
.
.
nd --> hyperplane

# %%
data.head(2)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0

# %%
x = data.iloc[: , 0:2]

# %%
# yx
x
# Out:
#       Hours Studied  Previous Scores
# 0                 7               99
# 1                 4               82
# 2                 8               51
# 3                 5               52
# 4                 7               75
# ...             ...              ...
# 9995              1               49
# 9996              7               64
# 9997              6               83
# 9998              9               97
# 9999              7               74
#
# [10000 rows x 2 columns]

# %%
y = data["Performance Index"]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test  = train_test_split(x, y, test_size = 0.3)

# %%
data.shape
# Out:
# (10000, 6)

# %%
x_train.shape
# Out:
# (7000, 2)

# %%
x_test.shape
# Out:
# (3000, 2)

# %%
y_train.shape
# Out:
# (7000,)

# %%
y_test.shape
# Out:
# (3000,)

# %%
from sklearn.linear_model import LinearRegression

# %%
mymodel = LinearRegression()

# %%
mymodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
mymodel.coef_
# Out:
# array([2.86617293, 1.02088246])

# %%
m = mymodel.coef_

# %%
mymodel.intercept_
# Out:
# -29.99091715275685

# %%
b = mymodel.intercept_

# %%
import joblib

# %%
joblib.dump(mymodel, "Student_Performance_model_checker.joblib")
# Out:
# ['Student_Performance_model_checker.joblib']
