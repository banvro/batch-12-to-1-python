# %%
# matplotlib:

# %%
# plot
# scatter
# # bar

# %%
# pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.array([10, 30, 40, 30, 60])

# %%
data
# Out:
# array([10, 30, 40, 30, 60])

# %%
x = ["Montly Revnew", "Yearly revnew", "Profit", "Loss", "Totle Income"]

colorx = ["green", "blue", "green", "red", "gray"]

# %%
plt.pie(data, labels = x, colors = colorx)

plt.title("Complany Info.01?)
# Out:
# Text(0.5, 1.0, 'Complany Info')
