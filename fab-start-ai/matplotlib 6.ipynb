# %%
import matplotlib.pyplot as plt
import numpy as  np

# %%
# plot

# %%
x = np.array([12, 23, 45, 24, 56, 78])
y = np.array([45, 67, 34, 44, 56, 34])

# %%
# scatter chart

# %%
plt.scatter(x, y, color = "red")

for i in range(len(x)):
    plt.text(x[i], y[i], f"({x[i]}, {y[i]})")

plt.xlabel("this is x labek")
plt.ylabel("this is y label")
plt.title("this is a title")
# Out:
# Text(0.5, 1.0, 'this is a title')

# %%
x = np.array([20, 30, 78, 67, 89, 90, 78, 67, 56])
y = np.array([10, 45, 65, 78, 78, 89, 67, 54, 34])

a = np.array([45, 67, 45, 4, 56])
b = np.array([45, 67, 78, 23, 100])

# %%
plt.scatter(x, y, color = "red", label = "Compalny Profy")
plt.scatter(a, b, color = "green", label = "Employee's INfo")

plt.legend(loc = "upper left")

# 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 
# 'upper center', 'center'

for i in range(len(x)):
    plt.text(x[i], y[i], f"({x[i]}, {y[i]})")

for i in range(len(a)):
    plt.text(a[i], b[i], f"({a[i]}, {y[i]})")

# %%
zx = np.array([10, 20, 30, 60, 55, 100])
ab = np.array([40, 50, 70, 50, 80, 30])

# %%
color = ["blue", "green", "red", "orange", "black", "purple"]
siz = [200, 300, 200, 300, 400, 300]

# %%
plt.scatter(zx, ab, label = "Compny prfout", color = color, sizes = siz)

plt.legend()
for i in range(len(zx)):
    plt.text(zx[i], ab[i], f"({zx[i]}, {ab[i]})", color = "red")

plt.xlabel("Complny profy")
plt.ylabel("Compamy ok")
plt.title("conpny data")

plt.grid(color = "green", linewidth = 1, linestyle = "dashdot")

# %%
import pandas as pd

# %%
data = pd.read_csv("zim_test.csv")

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
zx = data["Pulse"].values

# %%
# data.iloc[:, 1]
zx
# Out:
# array([110, 117, 103, 109, 117, 102, 110, 104, 109,  98, 103, 100, 106,
#        104,  98,  98, 100,  90, 103,  97, 108, 100, 130, 105, 102, 100,
#         92, 103, 100, 102,  92,  90, 101,  93, 107, 114, 102, 100, 100,
#        104,  90,  98, 100, 111, 111,  99, 109, 111, 108, 111, 107, 123,
#        106, 118, 136, 121, 118, 115, 153, 123, 108, 110, 109, 118, 110,
#         90, 105, 107, 106, 108,  97, 109, 100,  97, 114,  98, 105, 110,
#        100, 100, 159, 149, 103, 100, 100, 151, 102, 100, 129,  83, 101,
#        107,  90,  80, 150, 151,  95, 152, 109,  93,  95,  90,  90,  90,
#         92,  93,  90,  90,  90, 137, 102, 107, 124, 100, 108, 108, 116,
#         97, 105, 103, 112, 100, 119, 107, 111,  98,  97, 109,  99, 114,
#        104, 107, 103, 106, 103, 136, 117, 115, 113, 141, 108,  97, 100,
#        122, 136, 106, 107, 112, 103, 110, 106, 109, 109, 150, 105, 111,
#         97, 100, 114,  80,  85,  90,  95, 100, 105, 110, 115, 120, 125],
#       dtype=int64)

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
plt.scatter(data["Pulse"], data["Maxpulse"], color = "red")

plt.xlabel("Pulse")
plt.ylabel("Maxpulse")
plt.title("this is zim data")
plt.grid()
